# %% [markdown]
# # Week 1: Day 1 AM // Introduction: Data Science Toolbox

# %% [markdown]
# "Data Science" hampir sama luasnya dengan istilah itu. Mungkin paling mudah untuk menggambarkan apa itu dengan mendaftar komponen yang lebih konkret:
#
# **Data exploration & analysis.**
#
# - Termasuk di sini: Pandas; NumPy; SciPy; a helping hand from Python’s Standard Library.
#
# **Data visualization.** Nama yang cukup jelas. Mengambil data dan mengubahnya menjadi sesuatu yang berwarna.
#
# - Termasuk di sini:  Matplotlib; Seaborn; Plotly; others.
#
# **Classical machine learning**. Secara konseptual, kita dapat mendefinisikan ini sebagai tugas pembelajaran terawasi atau tidak terawasi yang bukan pembelajaran mendalam (lihat di bawah). Scikit-learn jauh-jauh dari alat untuk menerapkan klasifikasi, regresi, pengelompokan, dan pengurangan dimensi, sementara StatsModels kurang aktif dikembangkan tetapi masih memiliki sejumlah fitur yang berguna.
#
# - Termasuk di sini: Scikit-Learn, StatsModels.
#
# **Deep learning**. Ini adalah bagian dari pembelajaran mesin yang mengalami kebangkitan, dan umumnya diimplementasikan dengan Keras, di antara library lainnya. Ini telah melihat peningkatan yang luar biasa selama ~5 tahun terakhir, seperti AlexNet pada tahun 2012, yang merupakan desain pertama yang menggabungkan lapisan konvolusi berturut-turut.
#
# - Termasuk di sini: Keras and TensorFlow.
#
# **Data storage and big data frameworks.** Big Data paling baik didefinisikan sebagai data yang secara harfiah terlalu besar untuk ditempatkan pada satu mesin, atau tidak dapat diproses tanpa adanya lingkungan terdistribusi. Binding Python ke teknologi Apache sangat berperan di sini.
#
# - Apache Spark; Apache Hadoop; HDFS; Dask; h5py/pytables.
#
# **Odds and ends.** Termasuk subtopik seperti pemrosesan bahasa alami, dan manipulasi gambar dengan perpustakaan seperti OpenCV.
#
# - Termasuk di sini: nltk; Spacy; OpenCV/cv2; scikit-image; Cython.

# %% [markdown]
# ## Anaconda Basic
#
# Anaconda adalah distribusi bahasa pemrograman Python dan R untuk komputasi ilmiah, yang bertujuan untuk menyederhanakan manajemen dan penerapan paket. Distribusinya mencakup paket ilmu data yang cocok untuk Windows, Linux, dan macOS.
#
# Download Anaconda from [here](https://www.anaconda.com/products/individual).

# %% [markdown]
# ### Managing Conda
#
# Verifikasi bahwa conda diinstal dan berjalan di sistem Anda dengan mengetik di CMD:
#
# `conda --version`
#
# Conda menampilkan nomor versi yang telah Anda instal. Anda tidak perlu menavigasi ke direktori Anaconda.
#
# Contoh: `conda 4.7.12`
#
# Perbarui conda ke versi saat ini. Ketik berikut ini :
#
# `conda update conda`
#
# Conda membandingkan versi dan kemudian menampilkan apa yang tersedia untuk diinstal.
#
# Jika versi conda yang lebih baru tersedia, ketik y untuk memperbarui:
#
# `Proceed ([y]/n)? y`
#
# ### Managing Environtment
#
# Conda memungkinkan Anda membuat environments terpisah yang berisi file, paket, dan dependensinya yang tidak akan berinteraksi dengan environments lain.
#
# Saat Anda mulai menggunakan conda, Anda sudah memiliki environments default bernama base. Anda tidak ingin memasukkan program ke dalam environments dasar Anda. Buat environments terpisah untuk menjaga program Anda tetap terisolasi satu sama lain.
#
# Buat environments baru dan instal paket di dalamnya.
#
# Kami akan memberi nama environments `Hacktiv8` dan menginstal paket pandas. Di Anaconda Prompt atau di jendela terminal Anda, ketikkan yang berikut ini:
#
# `conda create --name Hacktiv8 pandas`
#
# Conda memeriksa untuk melihat paket tambahan ("dependensi") apa yang dibutuhkan panda, dan menanyakan apakah Anda ingin melanjutkan :
#
# `Proceed (y]/n)? y`
#
# Ketik "y" dan tekan Enter untuk melanjutkan.
#
# Untuk menggunakan, atau "mengaktifkan" environments baru, ketik berikut ini:
#
# ```sh
# Windows: conda activate Hacktiv8
#
# macOS and Linux: conda activate Hacktiv8
# ```
#
# Sekarang Anda berada di environments Hacktiv8 Anda, semua perintah conda yang Anda ketik akan masuk ke environments itu sampai Anda menonaktifkannya.
#
# Untuk melihat daftar semua environments Anda, ketik :
#
# `conda info --envs`
#
# Daftar environments muncul, mirip dengan berikut ini:
#
# ```sh
# conda environments:
#
#     base           /home/username/Anaconda3
#     snowflakes   * /home/username/Anaconda3/envs/snowflakes
# ```
#
# environments aktif adalah environments dengan tanda bintang (*).
#
# Ubah environments Anda saat ini kembali ke default (basis): `conda activate`
#
# ### Managing Python
#
# Saat Anda membuat environments baru, conda menginstal versi Python yang sama dengan yang Anda gunakan saat mengunduh dan menginstal Anaconda. Jika Anda ingin menggunakan versi Python yang berbeda, misalnya Python 3.6, cukup buat environments baru dan tentukan versi Python yang Anda inginkan.
#
# Buat lingkungan baru bernama "fox" yang berisi Python 3.6:
#
# `conda create --name fox python=3.6`
#
# Ketika conda bertanya apakah Anda ingin melanjutkan, ketik "y" dan tekan Enter.
#
# ### Managing Packages
#
# Di bagian ini, Anda memeriksa paket mana yang telah Anda instal, memeriksa mana yang tersedia dan mencari paket tertentu dan menginstalnya.
#
# Untuk menemukan paket yang telah Anda instal, aktifkan terlebih dahulu lingkungan yang ingin Anda cari. Lihat di atas untuk perintah untuk mengaktifkan lingkungan Hacktiv8 Anda.
#
# Periksa untuk melihat apakah paket yang belum Anda instal bernama "beautifulsoup4" tersedia dari repositori Anaconda (harus terhubung ke Internet):
#
# `conda search beautifulsoup4`
#
# Conda menampilkan daftar semua paket dengan nama itu di repositori Anaconda, jadi kami tahu itu tersedia.
#
# Instal paket ini ke lingkungan saat ini:
#
# `conda install beautifulsoup4`
#
# Periksa untuk melihat apakah program yang baru diinstal ada di lingkungan ini:
# `conda list`

# %% [markdown]
# ## The Notebooks
#
# ### JupyterLab
#
# JupyterLab adalah lingkungan pengembangan interaktif berbasis web untuk notebook, kode, dan data Jupyter. JupyterLab fleksibel: mengonfigurasi dan mengatur antarmuka pengguna untuk mendukung berbagai alur kerja dalam ilmu data, komputasi ilmiah, dan pembelajaran mesin. JupyterLab dapat diperluas dan modular: menulis plugin yang menambahkan komponen baru dan berintegrasi dengan yang sudah ada.
#
# ### Google Colab
#
# Colaboratory, atau singkatnya "Colab", memungkinkan Anda untuk menulis dan menjalankan Python di browser Anda, dengan
# - Konfigurasi nol diperlukan
# - Akses gratis ke GPU
# - Berbagi dengan mudah
# Baik Anda seorang pelajar, ilmuwan data, atau peneliti AI, Colab dapat mempermudah pekerjaan Anda.

# %% [markdown]
# # Latihan Pengaplikasian

# %% [markdown]
# ### Basic 1
#
# Mengunakan Jupyter Notebokk : untuk run nya CTRL + Enter
#
# - Basic dasar, menggunakan anaconda envirotment. Jika lewat anaconda, sih jupyter nya di instal aunch lalu klik new page jupyter. Di dalam web juptyer notebook, kita bisa menambahkan beberapa perintah. misalnya seperti berikut :
#
# - klik cmd anaconda lau tulis c:users\avita>jupter notebook. maka akan langsung nyambung ke web home page juptyet notebook

# %%
# Perkenalan Diri
# nama : ilmi
# batch 12
print('Hillidatul ilmi')
print('Peserta Batch 12')
# Out:
# Hillidatul ilmi
# Peserta Batch 12

# %% [markdown]
# ## Basic 2
#
# Mengunakan Visual studio code : untuk run nya CTRL + Run
#
# - jika di bandigkan dengan anaconda, lebih mudah menggunakan VSC. caranya bikin new folder atau create new folder dengan nama python, lalu bagian folder python ada menu "new file". new file tersebut bisa di ketik dengan Day1AM.ipynb. ipynb adalah jupyter notebook. misal klik perintah ini :
# - Kalau .ipynb itu jupyter, jika .py itu adalah python. Untuk .py maka tampilannya berbeda dari jupyter, untuk python hasil run ny ada di terminal.

# %%
print("apakabar")
a = 20 + 30
print(a)
# Out:
# apakabar
# 50

# %% [markdown]
# ## Basic 3
#
# Menggunakan Google Colab : run dengan cara mengklik bagian run
# - Kalau Google Colab tampilannya seperti jupyter notebook, tetapi run nya tingal di klik atau enter. Foldernya juga bisa di hubungkan dengan drive.
